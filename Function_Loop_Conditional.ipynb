# %% [markdown]
# ## นางสาวนิรชร บรรณสาร
# ## 603020474-9

# %% [markdown]
# # Function 🎨
# ### print ชื่อ XXX นามสกุล YYY รหัส ZZZ
# ### print เกรด วิชา Stat 1 >> AAA

# %%
a = 'ชื่อ นิรชร  นามสกุล บรรณสาร รหัส 6030204749'
print(a)
# Out:
# ชื่อ นิรชร  นามสกุล บรรณสาร รหัส 6030204749

# %%
name = 'นิรชร'
surname = 'บรรณสาร'
ID ='6030204749'
a = f'ชื่อ {name} นามสกุล {surname} รหัส {ID}'
print(a)
# Out:
# ชื่อ นิรชร นามสกุล บรรณสาร รหัส 6030204749

# %% [markdown]
# กำหนดนิยาม ตามด้วยชท่อของฟังก์ชั่น

# %% [markdown]
# ##  Function template
#   ```  python
#     def function_name(Input):
#    ``` python
#         do_something
#         return Output

# %%
def print_line1(name1,surname1,ID1):
    st =f'ชื่อ {name1} นามสกุล {surname1} รหัส {ID1}'

    return st

# %%
print(print_line1('กาญจนา','ประสาคุณ','603021855-2'))
# Out:
# ชื่อ กาญจนา นามสกุล ประสาคุณ รหัส 603021855-2

# %%
def print_2lines(name1,surname1,ID1,grade):
    st = f'ชื่อ {name1} นามสกุล {surname1} รหัส {ID1}'
    print(st)
    st2 = f'เกรดวิชา stat1 >>> {grade}'
    print(st2)

# %% [markdown]
# สั่งให้ปริ้น2 บรรทัด

# %%
print_2lines('กาญจนา','ประสาคุณ','603021855-2','A')
# Out:
# ชื่อ กาญจนา นามสกุล ประสาคุณ รหัส 603021855-2
# เกรดวิชา stat1 >>> A

# %%
print_2lines('นิรชร','บรรณสาร','603020474-9','A')
print_2lines('กาญจนา','พร้อมพรั่ง','603021856-0','A')
print_2lines('กมลวรรณ','มีป้อง','603021851-0','A')
# Out:
# ชื่อ นิรชร นามสกุล บรรณสาร รหัส 603020474-9
# เกรดวิชา stat1 >>> A
# ชื่อ กาญจนา นามสกุล พร้อมพรั่ง รหัส 603021856-0
# เกรดวิชา stat1 >>> A
# ชื่อ กมลวรรณ นามสกุล มีป้อง รหัส 603021851-0
# เกรดวิชา stat1 >>> A

# %% [markdown]
# รับเช้ามาแล้วรันบรรทัดแรก เมื่อเจอคำสั่งรีทินจะส่งอพ.ออกมา หลังจากรีเทินจะไม่ำงานอะไร

# %% [markdown]
# # fucntion without input

# %%
def two_three():
    x = 2*3
    return x

# %%
two_three()
# Out:
# 6

# %% [markdown]
# # function with default argument

# %%
def print_2lines_default(name1,surname1,ID1,grade='F'):
    st = f'ชื่อ {name1} นามสกุล {surname1} รหัส {ID1}'
    print(st)
    st2 = f'เกรดวิชา stat1 >>> {grade}'
    print(st2)

# %%
print_2lines_default('กาญจนา','ประสาคุณ','603021855-2')
# Out:
# ชื่อ กาญจนา นามสกุล ประสาคุณ รหัส 603021855-2
# เกรดวิชา stat1 >>> F

# %%
print_2lines_default('กาญจนา','ประสาคุณ','603021855-2','A+')
# Out:
# ชื่อ กาญจนา นามสกุล ประสาคุณ รหัส 603021855-2
# เกรดวิชา stat1 >>> A+

# %%
print_2lines_default(surname1 = 'กาญจนา' , name1 = 'ประสาคุณ',ID1 = '603021855-2')
# Out:
# ชื่อ ประสาคุณ นามสกุล กาญจนา รหัส 603021855-2
# เกรดวิชา stat1 >>> F

# %% [markdown]
# # 2

# %% [markdown]
# # Loop (วนซ้ำ)

# %% [markdown]
# ```python
# for each_member in listA:
#     do something
# ```

# %%
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# i ตัวแรกจะเข้ากับ1 แล้วก็มาเท่ากับสอง เท่ากับ3

# %%
for i in 'Nirachon':
    print(f'{i} -> / ')
# Out:
# N -> /
# i -> /
# r -> /
# a -> /
# c -> /
# h -> /
# o -> /
# n -> /

# %%
for i in 'Nirachon':
    print(f'{i} -> / ')
    print(' ')
# Out:
# N -> /
#
# i -> /
#
# r -> /
#
# a -> /
#
# c -> /
#
# h -> /
#
# o -> /
#
# n -> /

# %% [markdown]
# ## 1. สร้าง list ชื่อเพื่อนที่อยู่ในแถวยาวเดียวกัน
# ## 2. วนลูป print xประโยคว่า = ชื่อเรา  ความรู้สึก เพื่อน ทุกคน

# %%
list_F= ['ฝ้าย','แป้ง','เล็ก','ปิง','ป๊อป','ฟาง']
def print_feeling(XXX,YYY,ZZZ):
    print(f'{XXX}{YYY}{ZZZ}')

# %%
print_feeling('ฝ้าย','รัก','แป้ง')
# Out:
# ฝ้ายรักแป้ง

# %%
list_F= ['ฝ้าย','แป้ง','เล็ก','ปิง','ป๊อป','ฟาง']

# %%
def print_line_default(XXX,YYY,ZZZ):
    st = f'เราชื่อ {XXX} ความรู้สึก {YYY} เพื่อนชื่อ {ZZZ}'
    print(st)

# %%
print_line_default(XXX = 'บิวตี้' , YYY = 'รักเพื่อน',ZZZ = 'ฝ้าย')
print_line_default(XXX = 'บิวตี้' , YYY = 'รักเพื่อน',ZZZ = 'แป้ง')
print_line_default(XXX = 'บิวตี้' , YYY = 'รักเพื่อน',ZZZ = 'เล็ก')
print_line_default(XXX = 'บิวตี้' , YYY = 'รักเพื่อน',ZZZ = 'ปิง')
print_line_default(XXX = 'บิวตี้' , YYY = 'รักเพื่อน',ZZZ = 'ป๊อป')
print_line_default(XXX = 'บิวตี้' , YYY = 'รักเพื่อน',ZZZ = 'ฟาง')
# Out:
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ แป้ง
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ เล็ก
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ ปิง
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ ป๊อป
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ ฟาง

# %%
list_F =  ['ฝ้าย','แป้ง','เล็ก','ปิง','ป๊อป','ฟาง']

# %%
for x in list_F:
    print (x)
# Out:
# ฝ้าย
# แป้ง
# เล็ก
# ปิง
# ป๊อป
# ฟาง

# %% [markdown]
# # วนลูปเรียกฟังชันก์🎄

# %% [markdown]
# loop in function

# %%
def print_line_default(XXX,YYY,ZZZ):
    for f in ZZZ:
        print(f'เราชื่อ {XXX} ความรู้สึก {YYY} เพื่อนชื่อ {f}')

# %%
print_line_default('บิวตี้' ,'รักเพื่อน',list_F)
# Out:
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ แป้ง
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ เล็ก
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ ปิง
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ ป๊อป
# เราชื่อ บิวตี้ ความรู้สึก รักเพื่อน เพื่อนชื่อ ฟาง

# %% [markdown]
# f in ZZZ คือ วนลูปf ใน zzz ตรงเพื่อนชื่อ ใส่ f แทน

# %% [markdown]
# # วนลูปในdict 🎇

# %%
name_grade = {'นิรชร':'B','ศุภนิตา':'C','ปนัดดา':'A','ทรงกลด':'F'}
name_grade
# Out:
# {'นิรชร': 'B', 'ศุภนิตา': 'C', 'ปนัดดา': 'A', 'ทรงกลด': 'F'}

# %%
name_grade['ปนัดดา']
# Out:
# 'A'

# %%
name_grade.keys()
# Out:
# dict_keys(['นิรชร', 'ศุภนิตา', 'ปนัดดา', 'ทรงกลด'])

# %%
for i in name_grade.keys():
    print(f'{i} ได้เกรด {name_grade[i]}')
# Out:
# นิรชร ได้เกรด B
# ศุภนิตา ได้เกรด C
# ปนัดดา ได้เกรด A
# ทรงกลด ได้เกรด F

# %% [markdown]
# # loop in loop🌛

# %%
for name1 in list_F:
    for name2 in list_F:
        print_line_default(name1,'รักเพื่อน',list_F)
# Out:
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ แป้ง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ เล็ก
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ปิง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ป๊อป
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฟาง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ แป้ง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ เล็ก
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ปิง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ป๊อป
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฟาง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ แป้ง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ เล็ก
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ปิง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ป๊อป
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฟาง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# ...

# %% [markdown]
# # Conditional

# %% [markdown]
# ```python
# if conditional :
#     do somrthing
# elif condition2:
#     do another thing
# else :
#     do ```

# %% [markdown]
# ถ้าผ่านจะทำ ถ้าไม่ผ่านจะเช้คเงื่อนไขที่สองถ้าไม่ผ่านเงื่อไขสองไม่ผ่านเงื่อไขถัดมาไม่ผ่าน เงื่อนทั้งหมดไม่ผ่านก็จะทำอื่นๆ

# %% [markdown]
# ## ไม่อยากให้คนชื่อเดียวกันมารักกัน☹

# %%
for name1 in list_F:
    for name2 in list_F:  
        if name1 != name2:
                print_line_default(name1,'รักเพื่อน',list_F)
# Out:
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ แป้ง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ เล็ก
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ปิง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ป๊อป
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฟาง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ แป้ง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ เล็ก
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ปิง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ป๊อป
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฟาง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ แป้ง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ เล็ก
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ปิง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ป๊อป
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฟาง
# เราชื่อ ฝ้าย ความรู้สึก รักเพื่อน เพื่อนชื่อ ฝ้าย
# ...

# %%
if True:
    print('Yes')
# Out:
# Yes

# %% [markdown]
# หลัง if มีแค่ t,f

# %%
if False:
    print('No')

# %%
if False:
    print('yes')
else:
    print('No')
# Out:
# No

# %%
1 == 1
# Out:
# True

# %% [markdown]
# ข้างหน้าข้างหลังเหมือนกันหรือเปล่า ถ้าเหมือนปริ้นทรู

# %%
if 1 == 1:
    print('1=1')
# Out:
# 1=1

# %% [markdown]
# # ==,!=,>=,<=,>,<

# %% [markdown]
# #####  ถ้าเป็นไปตามนั้นจะตอบว่าtrue

# %% [markdown]
# ## HW เขียนฟังชันก์ตัดเกรด โดยที่ input เป็นคะแนน(0-100) output เป็นเกรด(F-A)
# input = [1,50,65,90,101,-5,49]

# %%
list_grade =  [1,50,65,90,101,-5,49]

# %%
for a in list_grade:
    if (a<=100) and (a>0):
        if(a>=80 ):
            print("Grade : A")
        elif (a>=75):
            print("Grade : B+")
        elif (a>=70):
            print("Grade : B")
        elif (a>=65):
            print("Grade : C+")
        elif (a>=60):
            print("Grade : C")    
        elif (a>=55):
            print("Grade : D+")
        elif (a>=50):
            print("Grade : D")
        elif (a>=49):
            print("Grade : F")
    else:
        print("Grade : No grade")
# Out:
# Grade : D
# Grade : C+
# Grade : A
# Grade : No grade
# Grade : No grade
# Grade : F
