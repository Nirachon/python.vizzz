# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## scatter plot

# %%
irisdata = pd.read_csv('C:\\Users\\Biw\\Documents\\viz_python\\python_dataviz\\iris.data',header=None)
irisdata
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# เอาแค่2 คอลัมน์

# %%
setosa_np =irisdata.iloc[:50,:-3].to_numpy()
setosa_np [:5,:]
# Out:
# array([[5.1, 3.5],
#        [4.9, 3. ],
#        [4.7, 3.2],
#        [4.6, 3.1],
#        [5. , 3.6]])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1])

# %% [markdown]
# ตัวอย่างเอาdataมาพลอท

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=6) #sเท่ากับอะไรก็ได้

# %%
setosa_np =irisdata.iloc[:50,:-1].to_numpy()
setosa_np [:5,:]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=setosa_np[:,2])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=20*setosa_np[:,2])

# %%
#กำหนดสีของทุกๆจุด

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=20*setosa_np[:,2],c='R')
# Out:
# C:\Users\Biw\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   """Entry point for launching an IPython kernel.

# %%
print(f'max = {max(setosa_np[:,3])}, min = {min(setosa_np[:,3])}')
# Out:
# max = 0.6, min = 0.1

# %%
#แบ่ง4ช่วง

# %%
colors = [ ]
for i in setosa_np[:,3]:
    if i < 0.15:
        colors.append('b')
    elif i < 0.3:
        colors.append('g')
    elif i < 0.45:
        colors.append('y')
    else:
        colors.append('r')
colors
# Out:
# ['g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'b',
#  'g',
#  'y',
#  'y',
#  'y',
#  'y',
#  'y',
#  'g',
#  'y',
#  'g',
#  'r',
#  'g',
#  'g',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'b',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'r',
#  'y',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g']

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c=colors)

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c=setosa_np[:,3],cmap='RdPu')

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c= np.array([[1,0.5,0.8]]))

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c=setosa_np[:,3],cmap='RdPu',marker='P')

# %% [markdown]
# # visualize2Data

# %% [markdown]
# 2อันลงในกราฟเดียวกันเพื่อดูว่า ต่างกันยังไง

# %%
versicolor_np = irisdata.iloc[50:100,:-1].to_numpy()

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c=setosa_np[:,3],cmap='RdPu',marker='P') 
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2],c=versicolor_np[:,3],cmap='RdPu',marker='X')

# %% [markdown]
# # visualize3Data

# %%
virginica_np = irisdata.iloc[100:,:-1].to_numpy()

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c=setosa_np[:,3],cmap='RdPu',marker='P') 
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2],c=versicolor_np[:,3],cmap='RdPu',marker='X') 
plt.scatter(virginica_np[:,0],virginica_np[:,1],s=30*virginica_np[:,2],c=virginica_np[:,3],cmap='RdPu',marker='+')

# %% [markdown]
# เทียบ3คลาสหลายแบบ แกน1เอก แกนวาย แกน3 ขนาด 4 สี ได้ทั้งหมด4*4

# %% [markdown]
# 1ขนาด 2สี 3 เอก 4 วาย

# %%
plt.scatter(setosa_np[:,1],setosa_np[:,0],s=30*setosa_np[:,3],c=setosa_np[:,2],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,1],versicolor_np[:,0],s=30*versicolor_np[:,3],c=versicolor_np[:,2],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,1],virginica_np[:,0],s=30*virginica_np[:,3],c=virginica_np[:,2],cmap='PuBu',marker='+')

# %%
plt.scatter(setosa_np[:,2],setosa_np[:,0],s=30*setosa_np[:,1],c=setosa_np[:,3],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,2],versicolor_np[:,0],s=30*versicolor_np[:,1],c=versicolor_np[:,3],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,2],virginica_np[:,0],s=30*virginica_np[:,1],c=virginica_np[:,3],cmap='PuBu',marker='+')

# %%
plt.scatter(setosa_np[:,1],setosa_np[:,3],s=30*setosa_np[:,0],c=setosa_np[:,2],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,1],versicolor_np[:,3],s=30*versicolor_np[:,0],c=versicolor_np[:,2],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,1],virginica_np[:,3],s=30*virginica_np[:,0],c=virginica_np[:,2],cmap='PuBu',marker='+')

# %%
plt.scatter(setosa_np[:,1],setosa_np[:,2],s=30*setosa_np[:,0],c=setosa_np[:,3],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,1],versicolor_np[:,2],s=30*versicolor_np[:,0],c=versicolor_np[:,3],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,1],virginica_np[:,2],s=30*virginica_np[:,0],c=virginica_np[:,3],cmap='PuBu',marker='+')

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,3],s=30*setosa_np[:,1],c=setosa_np[:,2],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,0],versicolor_np[:,3],s=30*versicolor_np[:,1],c=versicolor_np[:,2],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,0],virginica_np[:,3],s=30*virginica_np[:,1],c=virginica_np[:,2],cmap='PuBu',marker='+')

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,2],s=30*setosa_np[:,1],c=setosa_np[:,3],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,0],versicolor_np[:,2],s=30*versicolor_np[:,1],c=versicolor_np[:,3],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,0],virginica_np[:,2],s=30*virginica_np[:,1],c=virginica_np[:,3],cmap='PuBu',marker='+')

# %%
plt.scatter(setosa_np[:,3],setosa_np[:,0],s=30*setosa_np[:,1],c=setosa_np[:,2],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,3],versicolor_np[:,0],s=30*versicolor_np[:,1],c=versicolor_np[:,2],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,3],virginica_np[:,0],s=30*virginica_np[:,1],c=virginica_np[:,2],cmap='PuBu',marker='+')

# %%
plt.scatter(setosa_np[:,2],setosa_np[:,3],s=30*setosa_np[:,1],c=setosa_np[:,0],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,2],versicolor_np[:,3],s=30*versicolor_np[:,1],c=versicolor_np[:,0],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,2],virginica_np[:,3],s=30*virginica_np[:,1],c=virginica_np[:,0],cmap='PuBu',marker='+')

# %%
from matplotlib import pyplot as plt
import matplotlib

# %% [markdown]
# 4 แถว 2 หลัก ตัวที่เท่าไหร่

# %%
matplotlib.rcParams['figure.figsize'] = [16,16]
plt.subplot(4,2,1)
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=30*setosa_np[:,2],c=setosa_np[:,3],cmap='RdPu',marker='P') 
plt.scatter(versicolor_np[:,0],versicolor_np[:,1],s=30*versicolor_np[:,2],c=versicolor_np[:,3],cmap='RdPu',marker='X') 
plt.scatter(virginica_np[:,0],virginica_np[:,1],s=30*virginica_np[:,2],c=virginica_np[:,3],cmap='RdPu',marker='+') 
plt.subplot(4,2,2)
plt.scatter(setosa_np[:,2],setosa_np[:,0],s=30*setosa_np[:,1],c=setosa_np[:,3],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,2],versicolor_np[:,0],s=30*versicolor_np[:,1],c=versicolor_np[:,3],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,2],virginica_np[:,0],s=30*virginica_np[:,1],c=virginica_np[:,3],cmap='PuBu',marker='+') 
plt.subplot(4,2,3)
plt.scatter(setosa_np[:,1],setosa_np[:,3],s=30*setosa_np[:,0],c=setosa_np[:,2],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,1],versicolor_np[:,3],s=30*versicolor_np[:,0],c=versicolor_np[:,2],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,1],virginica_np[:,3],s=30*virginica_np[:,0],c=virginica_np[:,2],cmap='PuBu',marker='+') 
plt.subplot(4,2,4)
plt.scatter(setosa_np[:,1],setosa_np[:,2],s=30*setosa_np[:,0],c=setosa_np[:,3],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,1],versicolor_np[:,2],s=30*versicolor_np[:,0],c=versicolor_np[:,3],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,1],virginica_np[:,2],s=30*virginica_np[:,0],c=virginica_np[:,3],cmap='PuBu',marker='+') 
plt.subplot(4,2,5)
plt.scatter(setosa_np[:,0],setosa_np[:,3],s=30*setosa_np[:,1],c=setosa_np[:,2],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,0],versicolor_np[:,3],s=30*versicolor_np[:,1],c=versicolor_np[:,2],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,0],virginica_np[:,3],s=30*virginica_np[:,1],c=virginica_np[:,2],cmap='PuBu',marker='+') 
plt.subplot(4,2,6)
plt.scatter(setosa_np[:,0],setosa_np[:,2],s=30*setosa_np[:,1],c=setosa_np[:,3],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,0],versicolor_np[:,2],s=30*versicolor_np[:,1],c=versicolor_np[:,3],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,0],virginica_np[:,2],s=30*virginica_np[:,1],c=virginica_np[:,3],cmap='PuBu',marker='+') 
plt.subplot(4,2,7)
plt.scatter(setosa_np[:,3],setosa_np[:,0],s=30*setosa_np[:,1],c=setosa_np[:,2],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,3],versicolor_np[:,0],s=30*versicolor_np[:,1],c=versicolor_np[:,2],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,3],virginica_np[:,0],s=30*virginica_np[:,1],c=virginica_np[:,2],cmap='PuBu',marker='+') 
plt.subplot(4,2,8)
plt.scatter(setosa_np[:,2],setosa_np[:,3],s=30*setosa_np[:,1],c=setosa_np[:,0],cmap='PuBu',marker='P') 
plt.scatter(versicolor_np[:,2],versicolor_np[:,3],s=30*versicolor_np[:,1],c=versicolor_np[:,0],cmap='PuBu',marker='X') 
plt.scatter(virginica_np[:,2],virginica_np[:,3],s=30*virginica_np[:,1],c=virginica_np[:,0],cmap='PuBu',marker='+') 
plt.show()
